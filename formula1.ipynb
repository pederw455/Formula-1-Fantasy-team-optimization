# %%
names=["Hamilton","Verstappen","Russel","Leclerc","Perez","Sainz","Norris","Ricciardo","Gasly","Alanso","Ocon","Hulkenberg","Stroll","Bottas","Tsunoda","Guanyu","Albon","Latifi","Schumacker","Magnussen"]
price=[31,30.5,24,18,17.5,17,16,14.5,13.5,12.5,12,11.5,9.5,9,8.5,8.0,7.5,7.0,6.5,5.5]
points=[387.5,395.5,16,159,190,164.5,160,115,110,81,74,0,34,226,32,0,0,7,0,0]

# %%
from ortools.sat.python import cp_model
# DATA
capacity = 6
budget = 100 #mill



drivers_constructors = [ 
  {"name":"Hamilton",     "type":"driver","price":31, "score":387.5},
  {"name":"Verstappen",   "type":"driver","price":30.5, "score":395.5},
  {"name":"Russel",       "type":"driver","price":24, "score":226}, #Changed
  {"name":"Leclerc",      "type":"driver","price":18, "score":159},
  {"name":"Perez",        "type":"driver","price":17.5, "score":190},
  {"name":"Sainz",        "type":"driver","price":17, "score":164.5},
  {"name":"Norris",       "type":"driver","price":16, "score":160},
  {"name":"Ricciardo",    "type":"driver","price":14.5, "score":115},
  {"name":"Gasly",        "type":"driver","price":13.5, "score":110},
  {"name":"Alanso",       "type":"driver","price":12.5, "score":81},
  {"name":"Ocon",         "type":"driver","price":12, "score":74},
  {"name":"Hulkenberg",   "type":"driver","price":11.5, "score":43}, #Changed
  {"name":"Stroll",       "type":"driver","price":9.5, "score":34},
  {"name":"Bottas",       "type":"driver","price":9, "score":10},    #Changed
  {"name":"Tsunoda",      "type":"driver","price":8.5, "score":32},
  {"name":"Guanyu",       "type":"driver","price":8.0, "score":3},   #Changed
  {"name":"Albon",        "type":"driver","price":7.5, "score":16},  #Changed
  {"name":"Latifi",       "type":"driver","price":7.0, "score":7},
  {"name":"Schumacker",   "type":"driver","price":6.5, "score":0},
  {"name":"Magnussen",    "type":"driver","price":5.5, "score":1},   #Changed

  {"name":"MERCEDES",                      "type":"constructors","price":34.5, "score":613.5},
  {"name":"RED BULL RACING HONDA",         "type":"constructors","price":32.5, "score":585.5},
  {"name":"FERRARI",                       "type":"constructors","price":25, "score":323.5}, 
  {"name":"MCLAREN MERCEDES",              "type":"constructors","price":18.5, "score":275},
  {"name":"ALPINE RENAULT",                "type":"constructors","price":14, "score":155},
  {"name":"ALPHATAURI HONDA",              "type":"constructors","price":10.5, "score":142},
  {"name":"ASTON MARTIN MERCEDES",         "type":"constructors","price":11.5, "score":77}, 
  {"name":"WILLIAMS MERCEDES",             "type":"constructors","price":7, "score":23}, 
  {"name":"ALFA ROMEO RACING FERRARI",     "type":"constructors","price":8, "score":13},
  {"name":"HAAS FERRARI",                  "type":"constructors","price":6, "score":0},]


# PREPROCESSING
n_drivers_constructors = len(set([entry['name'] for entry in drivers_constructors]))

# MODEL
model = cp_model.CpModel()
x_select = [model.NewBoolVar('') for i in range(n_drivers_constructors)]

# Capacity constrain
model.Add(sum(x_select) == capacity)

# Budget constrain -> # ASSUMPTION: * 10 makes all the values integral
model.Add(sum([x_select[i] * int(round(drivers_constructors[i]['price']*10)) for i in range(n_drivers_constructors)]) <= budget * 10)

# Constructor constrain
model.Add(sum([x_select[i] for i in range(n_drivers_constructors) if drivers_constructors[i]['type'] == 'constructors']) == 1)


# Maximize sum of scores selected -> # ASSUMPTION: * 10 makes all the values integral
model.Maximize(sum([x_select[i] * int(round(drivers_constructors[i]['score']*10)) for i in range(n_drivers_constructors)]))

# SOLVE
solver = cp_model.CpSolver()
solver.parameters.log_search_progress = True
model.Proto().objective.scaling_factor = -1./10         #Inverse scaling for solver logging output
status = solver.Solve(model)

if status == cp_model.OPTIMAL:
  selected = [i for i in range(n_drivers_constructors) if solver.Value(x_select[i]) == 1]
  print("\n".join([str(drivers_constructors[i]) for i in selected]))
# Out:
# Starting CP-SAT solver v9.3.10497
# Parameters: log_search_progress: true
# Setting number of workers to 12
#
# Initial optimization model '':
# #Variables: 30 (#bools:28 in objective)
#   - 30 in [0,1]
# #kLinearN: 3 (#terms: 70)
#
# Starting presolve at 0.00s
# [ExtractEncodingFromLinear] #potential_supersets=1 #potential_subsets=0 #at_most_one_encodings=0 #exactly_one_encodings=0 #unique_terms=0 #multiple_terms=0 #literals=0 time=3.791e-06s
# [Probing] deterministic_time: 1.921e-05 (limit: 1) wall_time: 5.888e-05 (30/30)
# [Probing]  - new fixed Boolean: 2 (2/30)
# [Probing]  - new binary clause: 2
# [SAT presolve] num removable Booleans: 2 / 30
# [SAT presolve] num trivial clauses: 0
# [SAT presolve] [0s] clauses:36 literals:72 vars:13 one_side_vars:13 simple_definition:0 singleton_clauses:0
# [SAT presolve] [2.1529e-05s] clauses:9 literals:18 vars:13 one_side_vars:13 simple_definition:0 singleton_clauses:0
# [SAT presolve] [2.7868e-05s] clauses:9 literals:18 vars:13 one_side_vars:13 simple_definition:0 singleton_clauses:0
# [DetectDuplicateConstraints] #duplicates=0 time=3.7699e-05s
# [DetectDominatedLinearConstraints] #relevant_constraints=2 #work_done=252 #num_inclusions=1 #num_redundant=0 time=6.3406e-05s
# [DetectOverlappingColumns] #processed_columns=0 #work_done=0 #nz_reduction=0 time=4.99e-06s
# [ProcessSetPPC] #relevant_constraints=12 #num_inclusions=2 work=278 time=2.5249e-05s
# [Symmetry] Graph for symmetry has 86 nodes and 126 arcs.
# [Symmetry] Symmetry computation done. time: 1.5157e-05 dtime: 8.94e-06
# [Probing] deterministic_time: 1.351e-05 (limit: 1) wall_time: 4.1914e-05 (30/30)
# [Probing]  - new binary clause: 4
# [SAT presolve] num removable Booleans: 3 / 30
# [SAT presolve] num trivial clauses: 0
# [SAT presolve] [0s] clauses:63 literals:126 vars:13 one_side_vars:13 simple_definition:0 singleton_clauses:0
# [SAT presolve] [2.0751e-05s] clauses:9 literals:18 vars:13 one_side_vars:13 simple_definition:0 singleton_clauses:0
# [SAT presolve] [2.7808e-05s] clauses:9 literals:18 vars:13 one_side_vars:13 simple_definition:0 singleton_clauses:0
# [DetectDuplicateConstraints] #duplicates=0 time=4.1204e-05s
# [DetectDominatedLinearConstraints] #relevant_constraints=2 #work_done=208 #num_inclusions=1 #num_redundant=0 time=5.3318e-05s
# [DetectOverlappingColumns] #processed_columns=0 #work_done=0 #nz_reduction=0 time=4.121e-06s
# [ProcessSetPPC] #relevant_constraints=3 #num_inclusions=1 work=156 time=7.075e-06s
# [Symmetry] Graph for symmetry has 86 nodes and 125 arcs.
# [Symmetry] Symmetry computation done. time: 1.2242e-05 dtime: 8.83e-06
# [Probing] deterministic_time: 1.351e-05 (limit: 1) wall_time: 3.9769e-05 (30/30)
# [Probing]  - new binary clause: 4
# [SAT presolve] num removable Booleans: 3 / 30
# [SAT presolve] num trivial clauses: 0
# [SAT presolve] [0s] clauses:63 literals:126 vars:13 one_side_vars:13 simple_definition:0 singleton_clauses:0
# [SAT presolve] [1.8989e-05s] clauses:9 literals:18 vars:13 one_side_vars:13 simple_definition:0 singleton_clauses:0
# [SAT presolve] [2.3131e-05s] clauses:9 literals:18 vars:13 one_side_vars:13 simple_definition:0 singleton_clauses:0
# [DetectDuplicateConstraints] #duplicates=0 time=2.4944e-05s
# [DetectDominatedLinearConstraints] #relevant_constraints=2 #work_done=208 #num_inclusions=1 #num_redundant=0 time=4.2146e-05s
# [DetectOverlappingColumns] #processed_columns=0 #work_done=0 #nz_reduction=0 time=3.328e-06s
# [ProcessSetPPC] #relevant_constraints=3 #num_inclusions=1 work=156 time=6.076e-06s
# [Symmetry] Graph for symmetry has 86 nodes and 125 arcs.
# [Symmetry] Symmetry computation done. time: 1.0472e-05 dtime: 8.83e-06
#
# Presolve summary:
#   - 0 affine relations were detected.
#   - rule 'domination: added implications' was applied 166 times.
#   - rule 'exactly_one: removed literals' was applied 2 times.
#   - rule 'exactly_one: singleton' was applied 1 time.
#   - rule 'false enforcement literal' was applied 2 times.
#   - rule 'linear: divide by GCD' was applied 1 time.
#   - rule 'linear: fixed or dup variables' was applied 2 times.
#   - rule 'linear: positive equal one' was applied 1 time.
#   - rule 'linear: simplified rhs' was applied 2 times.
#   - rule 'objective: expanded objective constraint.' was applied 1 time.
#   - rule 'objective: variable not used elsewhere' was applied 2 times.
#   - rule 'presolve: 2 unused variables removed.' was applied 1 time.
#   - rule 'presolve: iteration' was applied 3 times.
#   - rule 'setppc: reduced linear coefficients.' was applied 2 times.
#
# Presolved optimization model '':
# #Variables: 27 (#bools:26 in objective)
#   - 27 in [0,1]
# #kAtMostOne: 1 (#literals: 7)
# #kBoolAnd: 23 (#enforced: 23) (#literals: 27)
# #kLinearN: 2 (#terms: 47)
#
# Preloading model.
# [Symmetry] Graph for symmetry has 83 nodes and 125 arcs.
# [Symmetry] Symmetry computation done. time: 1.0079e-05 dtime: 8.65e-06
# #Bound   0.00s best:-inf  next:[-0,4063]  initial_domain
#
# Starting Search at 0.00s with 12 workers.
# 10 full subsolvers: [default_lp, no_lp, max_lp, core, reduced_costs, pseudo_costs, quick_restart, quick_restart_no_lp, lb_tree_search, probing]
# Interleaved subsolvers: [feasibility_pump, rnd_var_lns_default, rnd_cst_lns_default, graph_var_lns_default, graph_cst_lns_default, rins_lns_default, rens_lns_default]
# #Bound   0.01s best:-inf  next:[-0,2559]  am1_presolve num_literals:26 num_am1:1 increase:3008 work_done:79
# #Bound   0.01s best:-inf  next:[-0,1191.5] default_lp initial_propagation
# #1       0.01s best:922.5 next:[923,1191.5] core fixed_bools:0/28
# #2       0.01s best:969   next:[969.5,1191.5] core fixed_bools:0/28
# #3       0.01s best:994   next:[994.5,1191.5] no_lp fixed_bools:0/27
# #4       0.01s best:1049  next:[1049.5,1191.5] no_lp fixed_bools:0/27
# #5       0.01s best:1086  next:[1086.5,1191.5] no_lp fixed_bools:0/27
# #6       0.01s best:1144  next:[1144.5,1191.5] no_lp fixed_bools:0/27
# #7       0.01s best:1165  next:[1165.5,1191.5] no_lp fixed_bools:0/27
# #Bound   0.01s best:1165  next:[1165.5,1188] max_lp
# #8       0.01s best:1188  next:[]         max_lp fixed_bools:9/27
# #Done    0.01s max_lp
#
# Sub-solver search statistics:
#   'max_lp':
#      LP statistics:
#        final dimension: 15 rows, 27 columns, 109 entries with magnitude in [1.421665e-01, 1.000000e+00]
#        total number of simplex iterations: 8
#        num solves:
#          - #OPTIMAL: 7
#        managed constraints: 17
#        total cuts added: 5 (out of 5 calls)
#          - 'CG': 2
#          - 'MIR_1': 1
#          - 'MIR_2': 1
#          - 'ZERO_HALF': 1
#
#   'reduced_costs':
#      LP statistics:
#        final dimension: 0 rows, 27 columns, 0 entries with magnitude in [0.000000e+00, 0.000000e+00]
#        total number of simplex iterations: 0
#        num solves:
#          - #DUAL_FEASIBLE: 1
#        managed constraints: 12
#        merged constraints: 18
#        total cuts added: 0 (out of 0 calls)
#
#   'pseudo_costs':
#      LP statistics:
#        final dimension: 6 rows, 27 columns, 91 entries with magnitude in [1.421665e-01, 1.000000e+00]
#        total number of simplex iterations: 6
#        num solves:
#          - #OPTIMAL: 3
#          - #DUAL_FEASIBLE: 1
#        managed constraints: 16
#        total cuts added: 4 (out of 4 calls)
#          - 'CG': 2
#          - 'MIR_1': 1
#          - 'MIR_2': 1
#
#   'lb_tree_search':
#      LP statistics:
#        final dimension: 5 rows, 27 columns, 82 entries with magnitude in [1.421665e-01, 1.000000e+00]
#        total number of simplex iterations: 6
#        num solves:
#          - #OPTIMAL: 3
#          - #DUAL_FEASIBLE: 1
#        managed constraints: 15
#        total cuts added: 3 (out of 3 calls)
#          - 'CG': 1
#          - 'MIR_1': 1
#          - 'MIR_2': 1
#
#
# Solutions found per subsolver:
#   'core': 2
#   'max_lp': 1
#   'no_lp': 5
#
# Objective bounds found per subsolver:
#   'am1_presolve': 1
#   'default_lp': 1
#   'initial_domain': 1
#   'max_lp': 1
#
# Improving variable bounds shared per subsolver:
#   'max_lp': 9
#
# CpSolverResponse summary:
# status: OPTIMAL
# objective: 1188
# best_bound: 1188
# booleans: 27
# conflicts: 0
# branches: 54
# propagations: 66
# integer_propagations: 122
# restarts: 54
# lp_iterations: 6
# walltime: 0.00882439
# usertime: 0.00882453
# deterministic_time: 0.000554097
# gap_integral: 0.0026305
#
# {'name': 'Verstappen', 'type': 'driver', 'price': 30.5, 'score': 395.5}
# {'name': 'Perez', 'type': 'driver', 'price': 17.5, 'score': 190}
# {'name': 'Albon', 'type': 'driver', 'price': 7.5, 'score': 16}
# {'name': 'Schumacker', 'type': 'driver', 'price': 6.5, 'score': 0}
# {'name': 'Magnussen', 'type': 'driver', 'price': 5.5, 'score': 1}
# {'name': 'RED BULL RACING HONDA', 'type': 'constructors', 'price': 32.5, 'score': 585.5}
